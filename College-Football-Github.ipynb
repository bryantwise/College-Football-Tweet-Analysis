# %% [markdown]
# # **Which Power 5 conference: the Big Ten Conference, the Big 12 Conference, the Atlantic Coast Conference (ACC), the Pac-12 Conference, or the Southeastern Conference (SEC), is the most negatively discussed in the United States on Twitter?**

# %%
# !pip install twarc --upgrade
# Out:
# ...
#      |████████████████████████████████| 54 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 98 kB 3.9 MB/s
# ...
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34546 sha256=3c41fa88cdc9aa0ba45be7d46f9e204c5e92f06263bebda5216d6dbfb14f1eae
#   Stored in directory: /root/.cache/pip/wheels/0d/c4/19/13d74440f2a571841db6b6e0a273694327498884dafb9cf978
# Successfully built configobj
# ...
#   Attempting uninstall: humanize
#     Found existing installation: humanize 0.5.1
#     Uninstalling humanize-0.5.1:
#       Successfully uninstalled humanize-0.5.1
# ...

# %%
# !twarc2 configure
# Out:
# 👋  Hi I don't see a configuration file yet, so let's make one.
#
# Please follow these steps:
#
# 1. visit https://developer.twitter.com/en/portal/
# 2. create a project and an app
# 3. go to your Keys and Tokens and generate your keys
#
# Please enter your Bearer Token (leave blank to skip to API key configuration): AAAAAAAAAAAAAAAAAAAAAHp9VwEAAAAAasRvFBDw4VnyRV%2FEQz5nBqbQBIQ%3DSiAHG5ykUFKK3D10f3ddJB06V74Na4x6hVHJOnb0Bxz4iPCXyM
# (Optional) Add API keys and secrets for user mode authentication [y or n]? y
# Please enter your API key: th22luJj3bfHfKiVP8bp7hjLJ
# Please enter your API secret: 0eUTWXAmjmZoeswXzO5X9RoNkdYe7ctyhY4x8bbvhKGw0hYDOR
#
# How would you like twarc to obtain your user keys?
#
# 1) generate access keys by visiting Twitter
# 2) manually enter your access token and secret
#
# Please enter your choice [1 or 2] 2
# Enter your Access Token: 1615347614-u0zZzVg7nJ7ll3rDLLfzpjTSN1ag7GyIjiSczbQ
# ...

# %%
import os
os.getcwd()
from google.colab import auth
auth.authenticate_user()
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import plotly.express as px

import pandas as pd
pd.options.display.max_colwidth = 400
pd.options.display.max_columns = 90

# %%
#SEC search queries
#Georgia
# !twarc2 search "godawgs"   --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/godawg-tweet-search.jsonl
#Florida
# !twarc2 search "gogators"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/gogators-tweet-search.jsonl
#Alabama
# !twarc2 search "rolltide"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/rolltide-tweet-search.jsonl
#South Carolina
# !twarc2 search "gamecocks"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/gamecocks-tweet-search.jsonl
#Arkansas
# !twarc2 search "razorbacks"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arkansas-tweet-search.jsonl
#Auburn
# !twarc2 search "wareagle"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/auburn-tweet-search.jsonl
#Kentucky
# !twarc2 search "kentuckyfootball" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kentucky-tweet-search.jsonl
#LSU
# !twarc2 search "lsufootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/lsu-tweet-search.jsonl
#Ole Miss
# !twarc2 search "olemissfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/olemiss-tweet-search.jsonl
#Mississippi State
# !twarc2 search "hailstate"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Mstate-tweet-search.jsonl
#Missouri
# !twarc2 search "mizzou"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Missouri-tweet-search.jsonl
#Vanderbilt
# !twarc2 search "Anchordown"  --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Vanderbilt-tweet-search.jsonl
#Tennesse 
# !twarc2 search "Vols"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Tennesse-tweet-search.jsonl
#Texas A&M
# !twarc2 search "TAMU"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/TexasAM-tweet-search.jsonl

# %%
#ACC search queries
#Georgia Tech
# !twarc2 search "gojackets"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/gojackets-tweet-search.jsonl
#Boston College
# !twarc2 search "WeAreBC"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/bostoncollege-tweet-search.jsonl
#Clemson
# !twarc2 search "#clemson" --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/clemson-tweet-search.jsonl
#Duke
# !twarc2 search "Duke_FB" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/duke-tweet-search.jsonl
#Florida State
# !twarc2 search "FSU"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/fsu-tweet-search.jsonl
#Louisville
# !twarc2 search "Louisvillefootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/louisville-tweet-search.jsonl
#Miami
# !twarc2 search "canesfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/miami-tweet-search.jsonl
#North Carolina
# !twarc2 search "tarheels"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/unc-tweet-search.jsonl
#NC State
# !twarc2 search "ncstatefootball" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ncstate-tweet-search.jsonl
#Pittsburgh
# !twarc2 search "pittfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pitt-tweet-search.jsonl
#Syracuse
# !twarc2 search "cusefootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/syracuse-tweet-search.jsonl
#Virginia
# !twarc2 search "uvafootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginia-tweet-search.jsonl
#Virginia Tech
# !twarc2 search "hokies"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginiatech-tweet-search.jsonl
#Wake Forest
# !twarc2 search "Godeacs" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wakeforest-tweet-search.jsonl
#Notre Dame
# !twarc2 search "ndfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/notredame-tweet-search.jsonl

# %%
#Big Ten count queries
#Illinois
# !twarc2 search "illini"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/illinois-tweet-search.jsonl
#Indiana
# !twarc2 search "iufb"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/indiana-tweet-search.jsonl
#Iowa
# !twarc2 search "iowahawkeyes"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowa-tweet-search.jsonl
#Maryland
# !twarc2 search "goterps"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/maryland-tweet-search.jsonl
#Michigan
# !twarc2 search "michiganfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michigan-tweet-search.jsonl
#Michigan State
# !twarc2 search "MSU_Football"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michiganstate-tweet-search.jsonl
#Minnesota
# !twarc2 search "GopherSports" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/minnesota-tweet-search.jsonl
#Nebraska
# !twarc2 search "GBR"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/nebraska-tweet-search.jsonl
#Northwestern
# !twarc2 search "B1GCats"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/northwestern-tweet-search.jsonl
#Ohio State
# !twarc2 search "#Buckeyes"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ohiostate-tweet-search.jsonl
#Penn State
# !twarc2 search "pennstate"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pennstate-tweet-search.jsonl
#Purdue
# !twarc2 search "boilerup"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/purdue-tweet-search.jsonl
#Rutgers
# !twarc2 search "RFootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/rutgers-tweet-search.jsonl
#Wisconsin
# !twarc2 search "#Badgers"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wisconsin-tweet-search.jsonl
# Out:
# Set --limit of 10000 reached:  93% 559617757/604770000 [01:37<00:07, 5741487.82it/s]
# 100% 604770000/604770000 [00:31<00:00, 19377920.65it/s]
# 100% 604770000/604770000 [00:03<00:00, 195956616.67it/s]
# 100% 604770000/604770000 [00:02<00:00, 242467102.26it/s]
# 100% 604770000/604770000 [00:46<00:00, 12981736.86it/s]
# 100% 604770000/604770000 [01:46<00:00, 5695393.91it/s]
# 100% 604770000/604770000 [00:41<00:00, 14640875.14it/s]
# Set --limit of 10000 reached:  35% 209424403/604770000 [01:35<03:00, 2190198.88it/s]
# 100% 604770000/604770000 [00:01<00:00, 440457078.19it/s]
# 100% 604770000/604770000 [01:13<00:00, 8176938.08it/s]
# 100% 604770000/604770000 [00:29<00:00, 20178367.87it/s]
# 100% 604770000/604770000 [00:23<00:00, 25258713.77it/s]
# 100% 604770000/604770000 [00:23<00:00, 26274299.68it/s]
# 100% 604770000/604770000 [01:03<00:00, 9569992.05it/s]

# %%
#Big 12 count queries
#Baylor
# !twarc2 search "#baylor"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/baylor-tweet-search.jsonl
#Iowa State
# !twarc2 search "#iowastate"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowastate-tweet-search.jsonl
#Kansas
# !twarc2 search "kufball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansas-tweet-search.jsonl
#Kansas State
# !twarc2 search "kstatefb"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansasstate-tweet-search.jsonl
#Oklahoma State
# !twarc2 search "gopokes"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahomastate-tweet-search.jsonl
#TCU
# !twarc2 search "Gofrogs"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/tcu-tweet-search.jsonl
#Texas Tech
# !twarc2 search "texastechfb" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texastech-tweet-search.jsonl
#West Virginia
# !twarc2 search "WVU"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/westvirgina-tweet-search.jsonl
#Texas
# !twarc2 search "HookEm"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texas-tweet-search.jsonl
#Oklahoma
# !twarc2 search "Sooners"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahoma-tweet-search.jsonl
# Out:
# 100% 604770000/604770000 [00:09<00:00, 60903689.89it/s]
# 100% 604770001/604770001 [00:04<00:00, 148451757.03it/s]
# 100% 604770000/604770000 [00:22<00:00, 27080962.13it/s]
# 100% 604770000/604770000 [00:27<00:00, 21788712.93it/s]
# Set --limit of 10000 reached:  28% 169974180/604770000 [01:46<04:31, 1600701.24it/s]
# 100% 604770000/604770000 [00:15<00:00, 40253409.83it/s]
# 100% 604770000/604770000 [00:55<00:00, 10842133.49it/s]
# 100% 604770000/604770000 [01:33<00:00, 6442413.49it/s]
# 100% 604770000/604770000 [01:37<00:00, 6208051.05it/s]
# Set --limit of 10000 reached:   5% 28993079/604770000 [09:03<2:59:46, 53379.29it/s]

# %%
#Pac-12 count queries
#Arizona
# !twarc2 search "beardown"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizona-tweet-search.jsonl
#Arizona State
# !twarc2 search "ASUFootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizonastate-tweet-search.jsonl
#California
# !twarc2 search "Calfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/cal-tweet-search.jsonl
#UCLA
# !twarc2 search "uclafootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ucla-tweet-search.jsonl
#Colorado
# !twarc2 search "CUBuffs"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/colorado-tweet-search.jsonl
#Oregon
# !twarc2 search "goducks"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregon-tweet-search.jsonl
#Oregon State
# !twarc2 search "gobeavs" --limit 10000   /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregonstate-tweet-search.jsonl
#USC
# !twarc2 search "uscfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/usc-tweet-search.jsonl
#Stanford
# !twarc2 search "gostanford"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/stanford-tweet-search.jsonl
#Utah
# !twarc2 search "goutes"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/utah-tweet-search.jsonl
#Washington
# !twarc2 search "washingtonfootball"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washington-tweet-search.jsonl
#Washington State
# !twarc2 search "gocougs"  --limit 10000  /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washingtonstate-tweet-search.jsonl

# %%
# !pip install twarc-csv
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 5.1 MB/s
# ...
#   Created wheel for twarc-csv: filename=twarc_csv-0.5.1-py3-none-any.whl size=9250 sha256=b9bdda648fb711bd2b7f60ad426a543c1c559075dd544ff3a635e3555a243bc6
#   Stored in directory: /root/.cache/pip/wheels/73/dc/97/79b383774eb06f882d070b3dfa18fad517c94c358d8a703e61
# Successfully built twarc-csv
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# ...

# %%
#SEC
#UGA
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/godawg-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/uga-tweet-search.csv
#Florida
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/gogators-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/florida-tweet-search.csv
#Alabama
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/rolltide-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/alabama-tweet-search.csv
#South Carolina
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/gamecocks-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/southcarolina-tweet-search.csv
#Arkansas
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arkansas-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arkansas-tweet-search.csv
#Auburn
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/auburn-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/auburn-tweet-search.csv
#Kentuky
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kentucky-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kentucky-tweet-search.csv
#LSU
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/lsu-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/lsu-tweet-search.csv
#Ole Miss
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/olemiss-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/olemiss-tweet-search.csv
#Mississippi State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Mstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Mstate-tweet-search.csv
#Missouri
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Missouri-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Missouri-tweet-search.csv
#Vanderbilt
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Vanderbilt-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Vanderbilt-tweet-search.csv
#Tennesse
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Tennesse-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Tennesse-tweet-search.csv
#Texas A&M
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/TexasAM-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/TexasAM-tweet-search.csv

# %%
UGA_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/godawg-tweet-search.csv')
florida_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/florida-tweet-search.csv')
alabama_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/alabama-tweet-search.csv')
southcarolina = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/southcarolina-tweet-search.csv')
arkansas_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arkansas-tweet-search.csv')
aurburn_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/auburn-tweet-search.csv')
kentucky_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kentucky-tweet-search.csv')
lsu_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/lsu-tweet-search.csv')
olemiss_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/olemiss-tweet-search.csv')
missstate_df =pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Mstate-tweet-search.csv')
missouri_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Missouri-tweet-search.csv')
vanderbilt_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Vanderbilt-tweet-search.csv')
tennesse_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/Tennesse-tweet-search.csv')
texasAM_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/TexasAM-tweet-search.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (31,33,34,35) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23,31,33,34,35) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (41) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23,41,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# ...

# %%
sec_teams = [UGA_df, florida_df, alabama_df, southcarolina, arkansas_df, aurburn_df, kentucky_df, lsu_df, olemiss_df, missstate_df, missouri_df, vanderbilt_df, tennesse_df, texasAM_df]

sec_df = pd.concat(sec_teams, axis = 0)
#sec_df.columns

# %%
sec_df.rename(columns={'created_at': 'date',
                          'public_metrics.retweet_count': 'retweets', 
                          'author.username': 'username', 
                          'author.name': 'name', 
                          'public_metrics.like_count': 'likes', 
                          'public_metrics.quote_count': 'quotes', 
                          'public_metrics.reply_count': 'replies'},
                            inplace=True)

# %%
#ACC
#Georgia Tech
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/gojackets-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/georgiatech-tweet-search.csv
#Boston College
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/bostoncollege-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/bostoncollege-tweet-search.csv
#Clemson
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/clemson-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/clemson-tweet-search.csv
#Duke
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/duke-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/duke-tweet-search.csv
#Florida State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/fsu-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/fsu-tweet-search.csv
#Louisville
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/louisville-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/louisville-tweet-search.csv
#Miami
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/miami-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/miami-tweet-search.csv
#North Carolina
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/unc-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/unc-tweet-search.csv
#NC State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ncstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ncstate-tweet-search.csv
#Pittsburgh
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pitt-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pitt-tweet-search.csv
#Syracuse
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/syracuse-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/syracuse-tweet-search.csv
#Virginia
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginia-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginia-tweet-search.csv
#Virginia Tech
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginiatech-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginiatech-tweet-search.csv
#Wake Forest
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wakeforest-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wakeforest-tweet-search.csv
#Notre Dame
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/notredame-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/notredame-tweet-search.csv

# %%
gt_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/georgiatech-tweet-search.csv')
bc_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/bostoncollege-tweet-search.csv')
clemson_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/clemson-tweet-search.csv')
duke_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/duke-tweet-search.csv')
fsu_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/fsu-tweet-search.csv')
louisville_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/louisville-tweet-search.csv')
miami_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/miami-tweet-search.csv')
unc_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/unc-tweet-search.csv')
ncstate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ncstate-tweet-search.csv')
pitt_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pitt-tweet-search.csv')
syracuse_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/syracuse-tweet-search.csv')
virginia_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginia-tweet-search.csv')
vtech_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/virginiatech-tweet-search.csv')
wakeforest_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wakeforest-tweet-search.csv')
notredame_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/notredame-tweet-search.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23,31,33,34,35,41,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (59,60) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
acc_teams = [gt_df, bc_df, clemson_df, duke_df, fsu_df, louisville_df, miami_df, unc_df, ncstate_df, pitt_df, syracuse_df, virginia_df, vtech_df, wakeforest_df, notredame_df]

acc_df = pd.concat(acc_teams, axis = 0)

# %%
acc_df.rename(columns={'created_at': 'date',
                          'public_metrics.retweet_count': 'retweets', 
                          'author.username': 'username', 
                          'author.name': 'name', 
                          'public_metrics.like_count': 'likes', 
                          'public_metrics.quote_count': 'quotes', 
                          'public_metrics.reply_count': 'replies'},
                            inplace=True)

# %%
#Big 10
#Illinois
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/illinois-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/illinois-tweet-search.csv
#Indiana
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/indiana-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/indiana-tweet-search.csv
#Iowa
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowa-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowa-tweet-search.csv
#Maryland
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/maryland-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/maryland-tweet-search.csv
#Michigan
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michigan-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michigan-tweet-search.csv
#Michigan State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michiganstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michiganstate-tweet-search.csv
#Minnesota
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/minnesota-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/minnesota-tweet-search.csv
#Nebraska
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/nebraska-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/nebraska-tweet-search.csv
#Northwestern
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/northwestern-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/northwestern-tweet-search.csv
#Ohio State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ohiostate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ohiostate-tweet-search.csv
#Penn State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pennstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/pennstate-tweet-search.csv
#Purdue
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/purdue-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/purdue-tweet-search.csv
#Wisconsin
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wisconsin-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wisconsin-tweet-search.csv
#Rutgers
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/rutgers-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/rutgers-tweet-search.csv

# %%
illinois_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/illinois-tweet-search.csv')
indiana_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/indiana-tweet-search.csv')
iowa_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowa-tweet-search.csv')
maryland_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/maryland-tweet-search.csv')
michigan_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michigan-tweet-search.csv')
msu_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/michiganstate-tweet-search.csv')
minnesota_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/minnesota-tweet-search.csv')
nebraska_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/nebraska-tweet-search.csv')
northwestern_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/northwestern-tweet-search.csv')
osu_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ohiostate-tweet-search.csv')
penn_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/penstate-tweet-search.csv')
purdue_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/purdue-tweet-search.csv')
wisconsin_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/wisconsin-tweet-search.csv')
rutgers_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/rutgers-tweet-search.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (31,33,34,35,41,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (20,21,23,58) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
big10_teams = [illinois_df, indiana_df, iowa_df, maryland_df, michigan_df, msu_df, minnesota_df, nebraska_df, 
               northwestern_df, osu_df, penn_df, purdue_df, wisconsin_df, rutgers_df]
big10_df = pd.concat(big10_teams, axis = 0)

# %%
big10_df.rename(columns={'created_at': 'date',
                          'public_metrics.retweet_count': 'retweets', 
                          'author.username': 'username', 
                          'author.name': 'name', 
                          'public_metrics.like_count': 'likes', 
                          'public_metrics.quote_count': 'quotes', 
                          'public_metrics.reply_count': 'replies'},
                            inplace=True)

# %%
#Big 12
#Baylor
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/baylor-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/baylor-tweet-search.csv
#Iowa State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowastate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowastate-tweet-search.csv
#Kansas
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansas-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansas-tweet-search.csv
#Kansas State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansasstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansasstate-tweet-search.csv
#Oklahoma State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahomastate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahomastate-tweet-search.csv
#TCU
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/tcu-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/tcu-tweet-search.csv
#Texas Tech
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texastech-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texastech-tweet-search.csv
#West Virginia
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/westvirgina-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/westvirginia-tweet-search.csv
#Texas
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texas-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texas-tweet-search.csv
#Oklahoma
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahoma-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahoma-tweet-search.csv

# %%
baylor_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/baylor-tweet-search.csv')
iowastate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/iowastate-tweet-search.csv')
kansas_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansas-tweet-search.csv')
kstate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/kansasstate-tweet-search.csv')
okstate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahomastate-tweet-search.csv')
tcu_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/tcu-tweet-search.csv')
texastech_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texastech-tweet-search.csv')
westv_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/westvirginia-tweet-search.csv')
texas_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/texas-tweet-search.csv')
oklahoma_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oklahoma-tweet-search.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (31,33,34,35,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (41) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
big12_teams = [baylor_df, iowastate_df, kansas_df, kstate_df, okstate_df, tcu_df, texastech_df, westv_df, texas_df, oklahoma_df]
big12_df = pd.concat(big12_teams, axis = 0)

# %%
big12_df.rename(columns={'created_at': 'date',
                          'public_metrics.retweet_count': 'retweets', 
                          'author.username': 'username', 
                          'author.name': 'name', 
                          'public_metrics.like_count': 'likes', 
                          'public_metrics.quote_count': 'quotes', 
                          'public_metrics.reply_count': 'replies'},
                            inplace=True)

# %%
#Pac-12
#Arizona
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizona-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizona-tweet-search.csv
#Arizona State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizonastate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizonastate-tweet-search.csv
#California
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/cal-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/cal-tweet-search.csv
#UCLA
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ucla-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ucla-tweet-search.csv
#Colorado
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/colorado-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/colorado-tweet-search.csv
#Oregon
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregon-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregon-tweet-search.csv
#Oregon State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregonstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregonstate-tweet-search.csv
#USC
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/usc-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/usc-tweet-search.csv
#Stanford
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/stanford-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/stanford-tweet-search.csv
#Utah
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/utah-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/utah-tweet-search.csv
#Washington
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washington-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washington-tweet-search.csv
#Washington State
# !twarc2 csv /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washingtonstate-tweet-search.jsonl /content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washingtonstate-tweet-search.csv
# Out:
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found
# /bin/bash: twarc2: command not found

# %%
arizona_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizona-tweet-search.csv')
arizstate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/arizonastate-tweet-search.csv')
cal_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/cal-tweet-search.csv')
ucla_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/ucla-tweet-search.csv')
colorado_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/colorado-tweet-search.csv')
oregon_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregon-tweet-search.csv')
ostate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/oregonstate-tweet-search.csv')
usc_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/usc-tweet-search.csv')
stanford_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/stanford-tweet-search.csv')
utah_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/utah-tweet-search.csv')
washington_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washington-tweet-search.csv')
wstate_df = pd.read_csv('/content/gdrive/MyDrive/QTM340-DataScienceText/twitter-data/washingtonstate-tweet-search.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (31,33,34,35,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (31,33,34,35,41,59,60) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
pac12_teams = [arizona_df, arizstate_df, cal_df, ucla_df, colorado_df, oregon_df, ostate_df, usc_df, stanford_df, 
               utah_df, washington_df, wstate_df]
pac12_df = pd.concat(pac12_teams, axis = 0)

# %%
pac12_df.rename(columns={'created_at': 'date',
                          'public_metrics.retweet_count': 'retweets', 
                          'author.username': 'username', 
                          'author.name': 'name', 
                          'public_metrics.like_count': 'likes', 
                          'public_metrics.quote_count': 'quotes', 
                          'public_metrics.reply_count': 'replies'},
                            inplace=True)

# %%
# !pip install tweet-preprocessor
import preprocessor as p

# %%
def preprocess_tweet(text):
    text = p.clean(text)
    return text

# %%
sec_df['text'] = sec_df['text'].apply(preprocess_tweet)
acc_df['text'] = acc_df['text'].apply(preprocess_tweet)
big10_df['text'] = big10_df['text'].apply(preprocess_tweet)
big12_df['text'] = big12_df['text'].apply(preprocess_tweet)
pac12_df['text'] = pac12_df['text'].apply(preprocess_tweet)

# %%
# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# ...
#      |████████████████████████████████| 125 kB 5.1 MB/s
# ...

# %%
sentimentAnalyser = SentimentIntensityAnalyzer()

# %%
def calculate_sentiment(text):
    # Run VADER on the text
    scores = sentimentAnalyser.polarity_scores(text)
    # Extract the compound score
    compound_score = scores['compound']
    # Return compound score
    return compound_score

# %%
def calculate_positive(text):
    # Run VADER on the text
    scores = sentimentAnalyser.polarity_scores(text)
    # Extract the compound score
    positive_score = scores['pos']
    # Return compound score
    return positive_score

# %%
def calculate_negative(text):
    # Run VADER on the text
    scores = sentimentAnalyser.polarity_scores(text)
    # Extract the compound score
    negative_score = scores['neg']
    # Return compound score
    return negative_score

# %%
#Sentiment Score
sec_df['sentiment_score'] = sec_df['text'].apply(calculate_sentiment)
acc_df['sentiment_score'] = acc_df['text'].apply(calculate_sentiment)
big10_df['sentiment_score'] = big10_df['text'].apply(calculate_sentiment)
big12_df['sentiment_score'] = big12_df['text'].apply(calculate_sentiment)
pac12_df['sentiment_score'] = pac12_df['text'].apply(calculate_sentiment)

#Positive Score
sec_df['positive_score'] = sec_df['text'].apply(calculate_positive)
acc_df['positive_score'] = acc_df['text'].apply(calculate_positive)
big10_df['positive_score'] = big10_df['text'].apply(calculate_positive)
big12_df['positive_score'] = big12_df['text'].apply(calculate_positive)
pac12_df['positive_score'] = pac12_df['text'].apply(calculate_positive)

#Negative Score
sec_df['negative_score'] = sec_df['text'].apply(calculate_negative)
acc_df['negative_score'] = acc_df['text'].apply(calculate_negative)
big10_df['negative_score'] = big10_df['text'].apply(calculate_negative)
big12_df['negative_score'] = big12_df['text'].apply(calculate_negative)
pac12_df['negative_score'] = pac12_df['text'].apply(calculate_negative)

# %%
# Categorizing the tweets as: Positive, Neutral, or Negative
sec_df['Sentiment']=''
sec_df.loc[sec_df['sentiment_score']>0,'Sentiment']='Positive'
sec_df.loc[sec_df['sentiment_score']==0,'Sentiment']='Neutral'
sec_df.loc[sec_df['sentiment_score']<0,'Sentiment']='Negative'


acc_df['Sentiment']=''
acc_df.loc[acc_df['sentiment_score']>0,'Sentiment']='Positive'
acc_df.loc[acc_df['sentiment_score']==0,'Sentiment']='Neutral'
acc_df.loc[acc_df['sentiment_score']<0,'Sentiment']='Negative'

big10_df['Sentiment']=''
big10_df.loc[big10_df['sentiment_score']>0,'Sentiment']='Positive'
big10_df.loc[big10_df['sentiment_score']==0,'Sentiment']='Neutral'
big10_df.loc[big10_df['sentiment_score']<0,'Sentiment']='Negative'

big12_df['Sentiment']=''
big12_df.loc[big12_df['sentiment_score']>0,'Sentiment']='Positive'
big12_df.loc[big12_df['sentiment_score']==0,'Sentiment']='Neutral'
big12_df.loc[big12_df['sentiment_score']<0,'Sentiment']='Negative'

pac12_df['Sentiment']=''
pac12_df.loc[pac12_df['sentiment_score']>0,'Sentiment']='Positive'
pac12_df.loc[pac12_df['sentiment_score']==0,'Sentiment']='Neutral'
pac12_df.loc[pac12_df['sentiment_score']<0,'Sentiment']='Negative'

# %%
sec_df = sec_df[['date', 'username', 'text', 'sentiment_score','positive_score',
                 'negative_score','likes', 'retweets', 'Sentiment']]
acc_df = acc_df[['date', 'username', 'text', 'sentiment_score','positive_score',
                 'negative_score','likes', 'retweets', 'Sentiment']]
big10_df = big10_df[['date', 'username', 'text', 'sentiment_score','positive_score',
                     'negative_score','likes', 'retweets', 'Sentiment']]
big12_df = big12_df[['date', 'username', 'text', 'sentiment_score','positive_score',
                     'negative_score','likes', 'retweets', 'Sentiment']]
pac12_df = pac12_df[['date', 'username', 'text', 'sentiment_score','positive_score',
                     'negative_score','likes', 'retweets', 'Sentiment']]

# %%
print("The average sentiment score of tweets related to the SEC is: \n", sec_df.sentiment_score.agg('mean'))
# Out:
# The average sentiment score of tweets related to the SEC is:
#  0.1877695142959165

# %%
print("The average sentiment score of tweets related to the ACC is: \n", acc_df.sentiment_score.agg('mean'))
# Out:
# The average sentiment score of tweets related to the ACC is:
#  0.1996478905678326

# %%
print("The average sentiment score of tweets related to the Big 10 is: \n", big10_df.sentiment_score.agg('mean'))
# Out:
# The average sentiment score of tweets related to the Big 10 is:
#  0.17292006306576901

# %%
print("The average sentiment score of tweets related to the Big 12 is: \n", big12_df.sentiment_score.agg('mean'))
# Out:
# The average sentiment score of tweets related to the Big 12 is:
#  0.2086738174068494

# %%
print("The average sentiment score of tweets related to the Pac-12 is: \n", pac12_df.sentiment_score.agg('mean'))
# Out:
# The average sentiment score of tweets related to the Pac-12 is:
#  0.1816389836624049

# %%
print("The SEC dataframe contains this many tweets\n",len(sec_df.index))
print("The ACC dataframe contains this many tweets\n",len(acc_df.index))
print("The Big 10 dataframe contains this many tweets\n",len(big10_df.index))
print("The Big 12 dataframe contains this many tweets\n",len(big12_df.index))
print("The PAC-12 dataframe contains this many tweets\n",len(pac12_df.index))
total = len(sec_df.index) + len(acc_df.index) + len(big10_df.index) + len(big12_df.index) + len(pac12_df.index)
print("Total tweets:\n" ,total)
# Out:
# The SEC dataframe contains this many tweets
#  95202
# The ACC dataframe contains this many tweets
#  46458
# The Big 10 dataframe contains this many tweets
#  46618
# The Big 12 dataframe contains this many tweets
#  52554
# The PAC-12 dataframe contains this many tweets
#  69288
# Total tweets:
#  310120

# %%
# Average Sentiment Score
sec_sentiment_avg = sec_df.sentiment_score.agg('mean')
acc_sentiment_avg = acc_df.sentiment_score.agg('mean')
big10_sentiment_avg = big10_df.sentiment_score.agg('mean')
big12_sentiment_avg = big12_df.sentiment_score.agg('mean')
pac12_sentiment_avg = pac12_df.sentiment_score.agg('mean')

# Average Positive Score
sec_positive_avg = sec_df.positive_score.agg('mean')
acc_positive_avg = acc_df.positive_score.agg('mean')
big10_positive_avg = big10_df.positive_score.agg('mean')
big12_positive_avg = big12_df.positive_score.agg('mean')
pac12_positive_avg = pac12_df.positive_score.agg('mean')

# Average Negative Score
sec_negative_avg = sec_df.negative_score.agg('mean')
acc_negative_avg = acc_df.negative_score.agg('mean')
big10_negative_avg = big10_df.negative_score.agg('mean')
big12_negative_avg = big12_df.negative_score.agg('mean')
pac12_negative_avg = pac12_df.negative_score.agg('mean')

# %%
sentiment_dat = pd.DataFrame(data= [sec_sentiment_avg, acc_sentiment_avg, big10_sentiment_avg, big12_sentiment_avg, pac12_sentiment_avg])
sentiment_dat["Conference"]= ['SEC', 'ACC', 'Big_10', 'Big_12', 'Pac-12']
sentiment_dat.rename(columns = { 0 : 'average_score'},
           inplace = True)
print(sentiment_dat)
# Out:
#    average_score Conference
# 0       0.162483        SEC
# 1       0.180267        ACC
# 2       0.148354     Big_10
# 3       0.196774     Big_12
# 4       0.163193     Pac-12

# %%
import seaborn as sns
import numpy as np


avg_plot = sns.barplot(x = 'Conference',
                    y = 'average_score',
                    ci = None,
                    data = sentiment_dat)
for p in avg_plot.patches: avg_plot.annotate(np.round(p.get_height(), decimals = 4),
                                             (p.get_x()+ p.get_width()/2., p.get_height()),
                                             ha = 'center', va = 'center', xytext = (0, -100),
                                             textcoords = 'offset points', color = 'white', fontweight = 'bold', fontsize = 11)
avg_plot.set(title = "Average Sentiment Score of Tweets by Conference",
             xlabel = 'Conference',
             ylabel = 'Average Sentiment Score');

# %%
pos_dat = pd.DataFrame(data= [sec_positive_avg, acc_positive_avg, big10_positive_avg, big12_positive_avg, pac12_positive_avg])
pos_dat["Conference"]= ['SEC', 'ACC', 'Big_10', 'Big_12', 'Pac-12']
pos_dat.rename(columns = { 0 : 'average_score'},
           inplace = True)
print(pos_dat)
# Out:
#    average_score Conference
# 0       0.116268        SEC
# 1       0.125835        ACC
# 2       0.112634     Big_10
# 3       0.138982     Big_12
# 4       0.112438     Pac-12

# %%
avg_pos_plot = sns.barplot(x = 'Conference',
                    y = 'average_score',
                    ci = None,
                    data = pos_dat)
for p in avg_pos_plot.patches: avg_pos_plot.annotate(np.round(p.get_height(), decimals = 4),
                                             (p.get_x()+ p.get_width()/2., p.get_height()),
                                             ha = 'center', va = 'center', xytext = (0, -100),
                                             textcoords = 'offset points', color = 'white', fontweight = 'bold', fontsize = 11)
avg_pos_plot.set(title = "Average Positive Score of Tweets by Conference",
             xlabel = 'Conference',
             ylabel = 'Average Positive Score');

# %%
neg_dat = pd.DataFrame(data= [sec_negative_avg, acc_negative_avg, big10_negative_avg, big12_negative_avg, pac12_negative_avg])
neg_dat["Conference"]= ['SEC', 'ACC', 'Big_10', 'Big_12', 'Pac-12']
neg_dat.rename(columns = { 0 : 'average_score'},
           inplace = True)
print(neg_dat)
# Out:
#    average_score Conference
# 0       0.037988        SEC
# 1       0.038258        ACC
# 2       0.050921     Big_10
# 3       0.041855     Big_12
# 4       0.036582     Pac-12

# %%
avg_neg_plot = sns.barplot(x = 'Conference',
                    y = 'average_score',
                    ci = None,
                    data = neg_dat)
for p in avg_neg_plot.patches: avg_neg_plot.annotate(np.round(p.get_height(), decimals = 4),
                                             (p.get_x()+ p.get_width()/2., p.get_height()),
                                             ha = 'center', va = 'center', xytext = (0, -100),
                                             textcoords = 'offset points', color = 'white', fontweight = 'bold', fontsize = 11)
avg_neg_plot.set(title = "Average Negative Score of Tweets by Conference",
             xlabel = 'Conference',
             ylabel = 'Average Negative Score');

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (5,5), dpi = 200)
ax = plt.subplot(111)
color = ['blue', 'red', 'forestgreen']
sec_plot = sec_df.groupby('Sentiment').size().plot(kind = 'pie', autopct = '%1.1f%%',
                                    fontsize = 12, colors = color, title = 'Proportion of Sentiment for SEC')
sec_plot.set_ylabel(' ');

# %%
fig = plt.figure(figsize = (5,5), dpi = 200)
ax = plt.subplot(111)
color = ['blue', 'red', 'forestgreen']
acc_plot = acc_df.groupby('Sentiment').size().plot(kind = 'pie', autopct = '%1.1f%%',
                                    fontsize = 12, colors = color, title = 'Proportion of Sentiment for ACC')
acc_plot.set_ylabel(' ');

# %%
fig = plt.figure(figsize = (5,5), dpi = 200)
ax = plt.subplot(111)
color = ['blue', 'red', 'forestgreen']
big10_plot = big10_df.groupby('Sentiment').size().plot(kind = 'pie', autopct = '%1.1f%%',
                                    fontsize = 12, colors = color, title = 'Proportion of Sentiment for BIG 10')
big10_plot.set_ylabel(' ');

# %%
fig = plt.figure(figsize = (5,5), dpi = 200)
ax = plt.subplot(111)
color = ['blue', 'red', 'forestgreen']
big12_plot = big12_df.groupby('Sentiment').size().plot(kind = 'pie', autopct = '%1.1f%%',
                                    fontsize = 12, colors = color, title = 'Proportion of Sentiment for BIG 12')
big12_plot.set_ylabel(' ');

# %%
fig = plt.figure(figsize = (5,5), dpi = 200)
ax = plt.subplot(111)
color = ['blue', 'red', 'forestgreen']
pac12_plot = pac12_df.groupby('Sentiment').size().plot(kind = 'pie', autopct = '%1.1f%%',
                                    fontsize = 12, colors = color, title = 'Proportion of Sentiment for Pac-12')
pac12_plot.set_ylabel(' ');

# %%
sec_df[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-554888aaff1a> in <module>()
# ----> 1 sec_df[:10]
#
# NameError: name 'sec_df' is not defined

# %%
#Topic model analysis
#get rid of emojis
#proportion of positive and negative tweets for each conference
